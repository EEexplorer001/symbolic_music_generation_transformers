# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# %cd '/content/drive/My Drive'
# !mkdir DLproject
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-0284c10dd6d7>", line 2, in <cell line: 2>
#     get_ipython().run_line_magic('cd', "'/content/drive/My Drive'")
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magic.py", line 187, in <lambda>
# ...

# %%
os.chdir('./DLproject')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-2257ce443d62>", line 1, in <cell line: 1>
#     os.chdir('./DLproject')
# OSError: [Errno 107] Transport endpoint is not connected: './DLproject'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
# !git clone https://github.com/atosystem/ThemeTransformer.git -b main --single-branch
# Out:
# fatal: destination path 'ThemeTransformer' already exists and is not an empty directory.

# %%
# %cd './ThemeTransformer'
# Out:
# /content/drive/My Drive/DLproject/ThemeTransformer

# %%
# !pip install -r './requirements.txt'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 63.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 86.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 90.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 2.1 MB/s eta 0:00:00
# ...
#   Created wheel for miditoolkit: filename=miditoolkit-0.1.14-py3-none-any.whl size=19537 sha256=8379f0d2d342ad01b38f6dfd6a8da6786bd128449cde5aa91bc96c93c78667b4
# ...

# %%
# !python train.py
# Out:
# Enter exp name : test1
# work dir exists! overwrite? [Y/N]:y
# Log file at : ./ckpts/test1/log/log_test1.txt
# Log file created : ./ckpts/test1/log/log_test1.txt
# Color Log file created : ./ckpts/test1/log/log_test1.txt_colored
# Exp_dir : ./ckpts/test1
# Exp_Name : test1
# {'max_src_len': 248, 'max_tgt_len': 513}
# {'max_src_len': 183, 'max_tgt_len': 513}
# Encoder layers #6
# Decoder layers #6
# Model hidden dim : 256
# Encoder Layers #6
# Decoder Layers #6
# Decoder Pattern #[0, 0, 0, 1, 1, 1]
# Batch size #8
# lr : 0.001
# Using device : cuda:0
# max epoch :15000
# Epoch 0 lr:0.0009 train_acc : 0.13 train_loss : 4.10  time:90.87 val_acc: 0.19 val_loss : 3.02
# Epoch 1 lr:0.0010 train_acc : 0.25 train_loss : 2.80  time:93.36 val_acc: 0.29 val_loss : 2.46
# Epoch 2 lr:0.0010 train_acc : 0.29 train_loss : 2.51  time:93.12 val_acc: 0.31 val_loss : 2.29
# Epoch 3 lr:0.0010 train_acc : 0.31 train_loss : 2.36  time:93.09 val_acc: 0.34 val_loss : 2.16
# ...

# %%
# !python inference.py --theme './theme_files/892_theme.mid' --model_path './ckpts/model_ep820.pt' --nbars 24 --out_midi './output/output_892.midi'
